# %% [markdown]
# # import the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_excel('Customer personality Analysis.xlsx')

# %%
df.head().T
# Out:
#                                        0                    1  \
# ID                                  5524                 2174
# Year_Birth                          1957                 1954
# Education                     Graduation           Graduation
# Marital_Status                    Single               Single
# Income                           58138.0              46344.0
# Kidhome                                0                    1
# Teenhome                               0                    1
# Dt_Customer          2012-09-04 00:00:00  2014-03-08 00:00:00
# Recency                               58                   38
# MntWines                             635                   11
# MntFruits                             88                    1
# MntMeatProducts                      546                    6
# MntFishProducts                      172                    2
# MntSweetProducts                      88                    1
# ...

# %%
df.head().T
# Out:
#                            0        1        2        3        4
# Education                  1        1        1        1        3
# Income               58138.0  46344.0  71613.0  26646.0  58293.0
# Kidhome                    0        1        0        1        1
# Teenhome                   0        1        0        0        0
# Recency                   58       38       26       26       94
# MntWines                 635       11      426       11      173
# MntFruits                 88        1       49        4       43
# MntMeatProducts          546        6      127       20      118
# MntFishProducts          172        2      111       10       46
# MntSweetProducts          88        1       21        3       27
# MntGoldProds              88        6       42        5       15
# NumDealsPurchases          3        2        1        2        5
# NumWebPurchases            8        1        8        2        5
# ...

# %%
df.shape
# Out:
# (2240, 29)

# %%
df.Recency.value_counts()
# Out:
# 56    37
# 30    32
# 54    32
# 46    31
# 92    30
#       ..
# 41    15
# 59    14
# 22    13
# 7     12
# 44    11
# Name: Recency, Length: 100, dtype: int64

# %%
df.shape
# Out:
# (2240, 29)

# %% [markdown]
# # Data Description
#
# •	ID: Customer's unique identifier
#
# •	Year_Birth: Customer's birth year
#
# •	Education: Customer's education level
#
# •	Marital_Status: Customer's marital status
#
# •	Income: Customer's yearly household income
#
# •	Kidhome: Number of children in customer's household
#
# •	Teenhome: Number of teenagers in customer's household
#
# •	Dt_Customer: Date of customer's enrollment with the company
#
# •	Recency: Number of days since customer's last purchase
#
# •	Complain: 1 if the customer complained in the last 2 years, 0 otherwise
# Products
# •	MntWines: Amount spent on wine in last 2 years
#
# •	MntFruits: Amount spent on fruits in last 2 years
#
# •	MntMeatProducts: Amount spent on meat in last 2 years
#
# •	MntFishProducts: Amount spent on fish in last 2 years
#
# •	MntSweetProducts: Amount spent on sweets in last 2 years
#
# •	MntGoldProds: Amount spent on gold in last 2 years
# Promotion
# •	NumDealsPurchases: Number of purchases made with a discount
#
# •	AcceptedCmp1: 1 if customer accepted the offer in the 1st campai
# gn, 0 otherwise
# •	AcceptedCmp2: 1 if customer accepted the offer in the 2nd campaign, 0 otherwise
#
# •	AcceptedCmp3: 1 if customer accepted the offer in the 3rd campaign, 0 otherwise
#
# •	AcceptedCmp4: 1 if customer accepted the offer in the 4th campaign, 0 otherwise
#
# •	AcceptedCmp5: 1 if customer accepted the offer in the 5th campaign, 0 otherwise
#
# •	Response: 1 if customer accepted the offer in the last campaign, 0 otherwise
# Place
# •	NumWebPurchases: Number of purchases made through the company’s website
#
# •	NumCatalogPurchases: Number of purchases made using a catalogue
#
# •	NumStorePurchases: Number of purchases made directly in stores
#
# •	NumWebVisitsMonth: Number of visits to company’s website in the last month

# %%
#Information of data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 29 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4   Income               2216 non-null   float64
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          2240 non-null   datetime64[ns]
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntGoldProds         2240 non-null   int64
# ...

# %% [markdown]
# totyal data in Marital_Statusis 2216 which is less then total data 2240 may be thre is null values in it.
#
# Education and Marital_statue this 2 columns is of String type & Dt_Customer is datetime type column.

# %% [markdown]
# #  Null_Values

# %%
df.isna().sum()
# Out:
# ID                      0
# Year_Birth              0
# Education               0
# Marital_Status          0
# Income                 24
# Kidhome                 0
# Teenhome                0
# Dt_Customer             0
# Recency                 0
# MntWines                0
# MntFruits               0
# MntMeatProducts         0
# MntFishProducts         0
# MntSweetProducts        0
# MntGoldProds            0
# NumDealsPurchases       0
# NumWebPurchases         0
# NumCatalogPurchases     0
# NumStorePurchases       0
# NumWebVisitsMonth       0
# AcceptedCmp3            0
# AcceptedCmp4            0
# AcceptedCmp5            0
# AcceptedCmp1            0
# AcceptedCmp2            0
# Complain                0
# Z_CostContact           0
# Z_Revenue               0
# Response                0
# dtype: int64

# %% [markdown]
# We have 24 missing values in Income column 24 is about 1% of data we can drop thrm from data.

# %%
#Dropping all the data present with null values
df=df.dropna()

# %%
#Data available after removing all null values.
df.shape
# Out:
# (2216, 29)

# %% [markdown]
# # Adding New Variables for more details

# %%
df.columns
# Out:
# Index(['ID', 'Year_Birth', 'Education', 'Marital_Status', 'Income', 'Kidhome',
#        'Teenhome', 'Dt_Customer', 'Recency', 'MntWines', 'MntFruits',
#        'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts',
#        'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases',
#        'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth',
#        'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5', 'AcceptedCmp1',
#        'AcceptedCmp2', 'Complain', 'Z_CostContact', 'Z_Revenue', 'Response'],
#       dtype='object')

# %% [markdown]
# 1st 'Age' :-  We can add this column by converting 'Year_Birth' Column.
#
# 2nd 'Total_Spend' :- We can add total spend column by adding all the 'Amount spent on diffrent prod' columns.
#
# 3rd 'Dt_Customer_year' :- We will add customers year of customer's enrollment with the company,
#
# 4th 'DT_Customer_month' :- We will add customers month of customer's enrollment with the company

# %%
# 1st 'Age'
df['Age']=2023-df['Year_Birth']

# %%
df.drop('Year_Birth',axis=1,inplace = True)

# %% [markdown]
# Created Age column using Year_Birth columns & then droped Year_Birth column from column

# %%
df.drop('ID',axis=1,inplace=True)

# %%
#2nd 'Total_Spend'
df['Total_Sped']=df['MntWines']+df['MntFruits']+df['MntMeatProducts']+df['MntFishProducts']+df['MntSweetProducts']+df['MntSweetProducts']

# %%
# 3rd 'Dt_Customer_year'
df['Dt_Customer_year'] =df['Dt_Customer'].dt.year 
# 4th 'DT_Customer_month'
df['Dt_Customer_Month'] =df['Dt_Customer'].dt.month

# %%
# dropping 'Dt_Customer' as we replaced it with 'Dt_Customer_year' & 'DT_Customer_month' columns
df.drop('Dt_Customer',axis=1,inplace=True)

# %%
# Number of customer enrolled in perticular year.
df['Dt_Customer_year'].value_counts()
# Out:
# 2013    1173
# 2014     553
# 2012     490
# Name: Dt_Customer_year, dtype: int64

# %%
df['Dt_Customer_year'].value_counts().plot(kind='bar')

# set the plot title and axis labels
plt.title('Value Counts of Dt_Customer_Year')
plt.xlabel('Month')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
# Number of customer enrolled in perticular month
df['Dt_Customer_Month'].value_counts()
# Out:
# 8     219
# 5     213
# 10    210
# 3     209
# 1     195
# 9     191
# 11    183
# 4     181
# 2     177
# 12    175
# 6     163
# 7     100
# Name: Dt_Customer_Month, dtype: int64

# %%
df['Dt_Customer_Month'].value_counts().plot(kind='bar')

# set the plot title and axis labels
plt.title('Value Counts of Dt_Customer_Monts')
plt.xlabel('Month')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
df.describe()
# Out:
#               Income      Kidhome     Teenhome      Recency     MntWines  \
# count    2216.000000  2216.000000  2216.000000  2216.000000  2216.000000
# mean    52247.251354     0.441787     0.505415    49.012635   305.091606
# std     25173.076661     0.536896     0.544181    28.948352   337.327920
# min      1730.000000     0.000000     0.000000     0.000000     0.000000
# 25%     35303.000000     0.000000     0.000000    24.000000    24.000000
# 50%     51381.500000     0.000000     0.000000    49.000000   174.500000
# 75%     68522.000000     1.000000     1.000000    74.000000   505.000000
# max    666666.000000     2.000000     2.000000    99.000000  1493.000000
#
#          MntFruits  MntMeatProducts  MntFishProducts  MntSweetProducts  \
# count  2216.000000      2216.000000      2216.000000       2216.000000
# mean     26.356047       166.995939        37.637635         27.028881
# std      39.793917       224.283273        54.752082         41.072046
# ...

# %% [markdown]
# # outliers

# %%
for col in df.columns:
    plt.hist(df[col], bins=20)
    plt.title(col)
    plt.xlabel('Value')
    plt.ylabel('Frequency')
    plt.show()

# %%
df.columns
# Out:
# Index(['Education', 'Marital_Status', 'Income', 'Kidhome', 'Teenhome',
#        'Recency', 'MntWines', 'MntFruits', 'MntMeatProducts',
#        'MntFishProducts', 'MntSweetProducts', 'MntGoldProds',
#        'NumDealsPurchases', 'NumWebPurchases', 'NumCatalogPurchases',
#        'NumStorePurchases', 'NumWebVisitsMonth', 'AcceptedCmp3',
#        'AcceptedCmp4', 'AcceptedCmp5', 'AcceptedCmp1', 'AcceptedCmp2',
#        'Complain', 'Z_CostContact', 'Z_Revenue', 'Response', 'Age',
#        'Total_Sped', 'Dt_Customer_year', 'Dt_Customer_Month'],
#       dtype='object')

# %%
for col in df.columns:
    if df[col].dtype != 'object' and df[col].dtype != 'datetime64[ns]':
        plt.boxplot(df[col])
        plt.title(col)
        plt.show()

# %% [markdown]
# Income Column

# %%
df[df.Income>110000]
# Out:
#        Education Marital_Status    Income  Kidhome  Teenhome  Recency  \
# 164          PhD        Married  157243.0        0         1       98
# 617          PhD       Together  162397.0        1         1       31
# 655   Graduation       Divorced  153924.0        0         0       81
# 687          PhD        Married  160803.0        0         0       21
# 1300      Master       Together  157733.0        1         0       37
# 1653  Graduation       Together  157146.0        0         0       13
# 1898         PhD         Single  113734.0        0         0        9
# 2132         PhD        Married  156924.0        0         0       85
# 2233  Graduation       Together  666666.0        1         0       23
#
#       MntWines  MntFruits  MntMeatProducts  MntFishProducts  ...  \
# 164         20          2             1582                1  ...
# 617         85          1               16                2  ...
# 655          1          1                1                1  ...
# ...

# %%
df=df[df.Income<110000]

# %% [markdown]
# MntWines Column

# %%
df[df.MntWines>1400]
# Out:
#        Education Marital_Status   Income  Kidhome  Teenhome  Recency  \
# 543          PhD        Married  84169.0        0         0        9
# 559   Graduation       Together  87771.0        0         1       61
# 824   Graduation       Together  87771.0        0         1       61
# 917          PhD        Married  84169.0        0         0        9
# 1488  Graduation        Married  76998.0        0         1       85
# 1641         PhD       Divorced  64140.0        0         2       71
# 1749         PhD        Married  80360.0        0         0       56
# 1961         PhD          Widow  71670.0        0         0        8
# 2098      Master        Married  81929.0        1         0       60
#
#       MntWines  MntFruits  MntMeatProducts  MntFishProducts  ...  \
# 543       1478         19              403                0  ...
# 559       1492         38              287               50  ...
# 824       1492         38              287               50  ...
# ...

# %%
df=df[df.MntWines<1400]

# %% [markdown]
# MntFruits Column

# %%
df[df.MntFruits>175]
# Out:
#        Education Marital_Status    Income  Kidhome  Teenhome  Recency  \
# 109       Master        Married   89058.0        0         0       18
# 198   Graduation        Married   86718.0        0         0       20
# 288   Graduation          Widow   79946.0        0         0       19
# 447   Graduation         Single   81246.0        0         0       87
# 591       Master        Married   92163.0        0         0       25
# 646   Graduation       Together  105471.0        0         0       36
# 753   Graduation        Married   80952.0        0         0       20
# 855   Graduation         Single   60474.0        0         1       25
# 1075  Graduation       Together   88347.0        0         0       32
# 1280  Graduation       Together   78687.0        0         0       13
# 1480  Graduation         Single   60474.0        0         1       25
# 1508         PhD        Married   78931.0        0         0       19
# ...

# %%
df=df[df.MntFruits<175]

# %% [markdown]
# MntMeatProducts Column

# %%
df[df.MntMeatProducts>1250]
# Out:
#      Education Marital_Status  Income  Kidhome  Teenhome  Recency  MntWines  \
# 21  Graduation        Married  2447.0        1         0       42         1
#
#     MntFruits  MntMeatProducts  MntFishProducts  ...  AcceptedCmp1  \
# 21          1             1725                1  ...             0
#
#     AcceptedCmp2  Complain  Z_CostContact  Z_Revenue  Response  Age  \
# 21             0         0              3         11         0   44
#
#     Total_Sped  Dt_Customer_year  Dt_Customer_Month
# 21        1730              2013                  1
#
# [1 rows x 30 columns]

# %%
df=df[df.MntMeatProducts<1250]

# %% [markdown]
# MntFishProducts Column

# %%
df[df.MntFishProducts>225]
# Out:
#        Education Marital_Status   Income  Kidhome  Teenhome  Recency  \
# 45    Graduation         Single  79941.0        0         0       72
# 214   Graduation        Married  70951.0        0         0       66
# 492   Graduation       Together  76005.0        0         0       72
# 626   Graduation         Single  84196.0        0         1       56
# 766   Graduation        Married  74985.0        0         0        8
# 779   Graduation         Single  72258.0        0         1       28
# 914   Graduation         Single  95529.0        0         0       29
# 924   Graduation       Together  83033.0        1         0       82
# 926   Graduation        Married  77583.0        0         0       93
# 1010  Graduation       Together  77568.0        0         1       30
# 1089         PhD         Single  71691.0        0         0        0
# 1157  Graduation       Together  56715.0        0         0       52
# 1199    2n Cycle          Widow  59184.0        0         1        6
# ...

# %%
df= df[df.MntFishProducts<225]

# %% [markdown]
# MntGoldProds Column

# %%
df[df.MntGoldProds>250]
# Out:
#        Education Marital_Status  Income  Kidhome  Teenhome  Recency  MntWines  \
# 1328      Master         Single  6560.0        0         0        2        67
# 1806         PhD         Single  7144.0        0         2       92        81
# 1975  Graduation        Married  4428.0        0         1        0        16
#
#       MntFruits  MntMeatProducts  MntFishProducts  ...  AcceptedCmp1  \
# 1328         11               26                4  ...             0
# 1806          4               33                5  ...             0
# 1975          4               12                2  ...             0
#
#       AcceptedCmp2  Complain  Z_CostContact  Z_Revenue  Response  Age  \
# 1328             0         0              3         11         0   41
# 1806             0         0              3         11         0   57
# 1975             0         0              3         11         0   54
#
#       Total_Sped  Dt_Customer_year  Dt_Customer_Month
# ...

# %%
df=df[df.MntGoldProds<250]

# %% [markdown]
# MntSweetProducts Column

# %%
df[df.MntSweetProducts>175]
# Out:
#        Education Marital_Status    Income  Kidhome  Teenhome  Recency  \
# 40    Graduation        Married   80011.0        0         1        3
# 203          PhD       Together  102160.0        0         0       54
# 347   Graduation       Divorced   84835.0        0         0        0
# 456     2n Cycle         Single   89572.0        0         0       44
# 461   Graduation          Widow   70165.0        0         0       60
# 470   Graduation        Married   61456.0        0         1       47
# 557   Graduation        Married   79908.0        0         0       30
# 634   Graduation         Single   83917.0        0         0       12
# 780          PhD         Single   71466.0        0         0       86
# 1253  Graduation        Married   74716.0        0         1       92
# 1259  Graduation       Together   76653.0        0         0       91
# 1333  Graduation         Single   90842.0        0         0       57
# ...

# %%
df=df[df.MntSweetProducts<175]

# %% [markdown]
# NumDealsPurchases Columns

# %%
df[df.NumDealsPurchases>14]
# Out:
#        Education Marital_Status   Income  Kidhome  Teenhome  Recency  \
# 432     2n Cycle       Together  67309.0        1         1       76
# 1042  Graduation         Single   8028.0        0         0       62
# 1245  Graduation       Divorced   1730.0        0         0       65
# 1846         PhD        Married   4023.0        1         1       29
#
#       MntWines  MntFruits  MntMeatProducts  MntFishProducts  ...  \
# 432        515         47              181              149  ...
# 1042        73         18               66                7  ...
# 1245         1          1                3                1  ...
# 1846         5          0                1                1  ...
#
#       AcceptedCmp1  AcceptedCmp2  Complain  Z_CostContact  Z_Revenue  \
# 432              0             0         0              3         11
# 1042             0             0         0              3         11
# 1245             0             0         0              3         11
# ...

# %%
df=df[df.NumDealsPurchases<14]

# %% [markdown]
# NumWebPurchases Column

# %%
df[df.NumWebPurchases>20]
# Out:
# Empty DataFrame
# Columns: [Education, Marital_Status, Income, Kidhome, Teenhome, Recency, MntWines, MntFruits, MntMeatProducts, MntFishProducts, MntSweetProducts, MntGoldProds, NumDealsPurchases, NumWebPurchases, NumCatalogPurchases, NumStorePurchases, NumWebVisitsMonth, AcceptedCmp3, AcceptedCmp4, AcceptedCmp5, AcceptedCmp1, AcceptedCmp2, Complain, Z_CostContact, Z_Revenue, Response, Age, Total_Sped, Dt_Customer_year, Dt_Customer_Month]
# Index: []
#
# [0 rows x 30 columns]

# %% [markdown]
# NumWebVisitsMonth Column

# %%
df[df.NumWebVisitsMonth>13]
# Out:
#        Education Marital_Status  Income  Kidhome  Teenhome  Recency  MntWines  \
# 9            PhD       Together  5648.0        1         1       68        28
# 774          PhD       Together  6835.0        0         1       76       107
# 981   Graduation       Divorced  4861.0        0         0       20         2
# 1524  Graduation         Single  3502.0        1         0       56         2
#
#       MntFruits  MntMeatProducts  MntFishProducts  ...  AcceptedCmp1  \
# 9             0                6                1  ...             0
# 774           2               12                2  ...             0
# 981           1                1                1  ...             0
# 1524          1                1                0  ...             0
#
#       AcceptedCmp2  Complain  Z_CostContact  Z_Revenue  Response  Age  \
# 9                0         0              3         11         0   73
# 774              0         0              3         11         0   66
# ...

# %%
df=df[df.NumWebVisitsMonth<13]

# %% [markdown]
# NumCatalogPurchases Column

# %%
df[df.NumCatalogPurchases>25]
# Out:
# Empty DataFrame
# Columns: [Education, Marital_Status, Income, Kidhome, Teenhome, Recency, MntWines, MntFruits, MntMeatProducts, MntFishProducts, MntSweetProducts, MntGoldProds, NumDealsPurchases, NumWebPurchases, NumCatalogPurchases, NumStorePurchases, NumWebVisitsMonth, AcceptedCmp3, AcceptedCmp4, AcceptedCmp5, AcceptedCmp1, AcceptedCmp2, Complain, Z_CostContact, Z_Revenue, Response, Age, Total_Sped, Dt_Customer_year, Dt_Customer_Month]
# Index: []
#
# [0 rows x 30 columns]

# %% [markdown]
# Age column

# %%
df[df.Age > 90]
# Out:
#     Education Marital_Status   Income  Kidhome  Teenhome  Recency  MntWines  \
# 192  2n Cycle       Divorced  36640.0        1         0       99        15
# 239  2n Cycle         Single  60182.0        0         1       23         8
# 339       PhD       Together  83532.0        0         0       36       755
#
#      MntFruits  MntMeatProducts  MntFishProducts  ...  AcceptedCmp1  \
# 192          6                8                7  ...             0
# 239          0                5                7  ...             0
# 339        144              562              104  ...             0
#
#      AcceptedCmp2  Complain  Z_CostContact  Z_Revenue  Response  Age  \
# 192             0         1              3         11         0  123
# 239             0         0              3         11         0  130
# 339             0         0              3         11         0  124
#
#      Total_Sped  Dt_Customer_year  Dt_Customer_Month
# ...

# %%
df=df[df.Age<90]

# %% [markdown]
# Total_Spend Column

# %%
df[df.Total_Sped>2500]
# Out:
#        Education Marital_Status   Income  Kidhome  Teenhome  Recency  \
# 1179      Master         Single  90638.0        0         0       29
# 1492  Graduation       Together  87679.0        0         0       62
# 1572      Master         Single  90638.0        0         0       29
#
#       MntWines  MntFruits  MntMeatProducts  MntFishProducts  ...  \
# 1179      1156        120              915               94  ...
# 1492      1259        172              815               97  ...
# 1572      1156        120              915               94  ...
#
#       AcceptedCmp1  AcceptedCmp2  Complain  Z_CostContact  Z_Revenue  \
# 1179             0             0         0              3         11
# 1492             1             0         0              3         11
# 1572             0             0         0              3         11
#
#       Response  Age  Total_Sped  Dt_Customer_year  Dt_Customer_Month
# 1179         0   32        2573              2014                  2
# ...

# %%
df=df[df.Total_Sped<2500]

# %% [markdown]
# Education column

# %%
df.Education.value_counts()
# Out:
# Graduation    1059
# PhD            459
# Master         355
# 2n Cycle       189
# Basic           54
# Name: Education, dtype: int64

# %%
sns.countplot(df.Education)
plt.ylabel('Education')
plt.title('Count Plot of Categorical Column (Education)')
plt.show()
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# Insights:-
# Value count of Basic is very low as compare to others,
#
# Lets combined Basics and 2nd Cycle as in one variable Undergraduated.

# %%
#Replacing 'Basics' and '2nd Cycle' with 'Undergraduation'
df['Education']=np.where(df['Education']== 'Basic','Undergraduation',
         np.where(df['Education']=='2n Cycle','Undergraduation',df['Education']))

# %%
df.Education.value_counts()
# Out:
# Graduation         1059
# PhD                 459
# Master              355
# Undergraduation     243
# Name: Education, dtype: int64

# %%
sns.countplot(df.Education)
plt.ylabel('Education')
plt.title('Count Plot of Categorical Column (Education)')
plt.show()
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# Marital_Statues Column

# %%
df.Marital_Status.value_counts()
# Out:
# Married     822
# Together    544
# Single      449
# Divorced    225
# Widow        69
# Alone         3
# Absurd        2
# YOLO          2
# Name: Marital_Status, dtype: int64

# %%
sns.countplot(df.Marital_Status)
plt.ylabel('Marital_Status')
plt.title('Count Plot of Categorical Column (Marital_Status)')
plt.show()
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# Insights:-
#
# Counts of Alone, Absurd, YOLO is Coumbined single degits we can drop tyhem as its outliers and can affect our model.
#
# We can combined Divorced, Widow and Single cetegories in new combined cetegory unmarried
#
# & other Together And Married cetegories in new combined cetegory married

# %%
df[(df.Marital_Status=='Alone') ]
# Out:
#       Education Marital_Status   Income  Kidhome  Teenhome  Recency  MntWines  \
# 131      Master          Alone  61331.0        1         1       42       534
# 138         PhD          Alone  35860.0        1         1       37        15
# 153  Graduation          Alone  34176.0        1         0       12         5
#
#      MntFruits  MntMeatProducts  MntFishProducts  ...  AcceptedCmp1  \
# 131          5               47                0  ...             0
# 138          0                8                4  ...             0
# 153          7               24               19  ...             0
#
#      AcceptedCmp2  Complain  Z_CostContact  Z_Revenue  Response  Age  \
# 131             0         0              3         11         0   65
# 138             0         0              3         11         1   50
# 153             0         0              3         11         0   35
#
#      Total_Sped  Dt_Customer_year  Dt_Customer_Month
# ...

# %%
df[(df.Marital_Status=='Absurd') ]
# Out:
#        Education Marital_Status   Income  Kidhome  Teenhome  Recency  \
# 2093  Graduation         Absurd  79244.0        0         0       58
# 2134      Master         Absurd  65487.0        0         0       48
#
#       MntWines  MntFruits  MntMeatProducts  MntFishProducts  ...  \
# 2093       471        102              125              212  ...
# 2134       240         67              500              199  ...
#
#       AcceptedCmp1  AcceptedCmp2  Complain  Z_CostContact  Z_Revenue  \
# 2093             1             0         0              3         11
# 2134             0             0         0              3         11
#
#       Response  Age  Total_Sped  Dt_Customer_year  Dt_Customer_Month
# 2093         1   30        1032              2012                 12
# 2134         0   66        1006              2014                  1
#
# [2 rows x 30 columns]

# %%
df[(df.Marital_Status=='YOLO')]
# Out:
#      Education Marital_Status   Income  Kidhome  Teenhome  Recency  MntWines  \
# 2177       PhD           YOLO  48432.0        0         1        3       322
# 2202       PhD           YOLO  48432.0        0         1        3       322
#
#       MntFruits  MntMeatProducts  MntFishProducts  ...  AcceptedCmp1  \
# 2177          3               50                4  ...             0
# 2202          3               50                4  ...             0
#
#       AcceptedCmp2  Complain  Z_CostContact  Z_Revenue  Response  Age  \
# 2177             0         0              3         11         0   50
# 2202             0         0              3         11         1   50
#
#       Total_Sped  Dt_Customer_year  Dt_Customer_Month
# 2177         385              2012                 10
# 2202         385              2012                 10
#
# [2 rows x 30 columns]

# %%
df.drop([2177,2202,2093,2134,153,138,131],inplace=True)

# %%
df.Marital_Status.value_counts()
# Out:
# Married     822
# Together    544
# Single      449
# Divorced    225
# Widow        69
# Name: Marital_Status, dtype: int64

# %%
df['Marital_Status']=np.where(df['Marital_Status']== 'Married','Married',
         np.where(df['Marital_Status']=='Together','Married',
                 np.where(df['Marital_Status']=='Single','Unmarried',
                         np.where(df['Marital_Status']=='Divorced','Unmarried',
                                 np.where(df['Marital_Status']=='Widow','Unmarried',df['Marital_Status'])))))

# %%
df.Marital_Status.value_counts()
# Out:
# Married      1366
# Unmarried     743
# Name: Marital_Status, dtype: int64

# %%
sns.countplot(df.Marital_Status)
plt.ylabel('Marital_Status')
plt.title('Count Plot of Categorical Column (Marital_Status)')
plt.show()
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df.shape
# Out:
# (2109, 30)

# %%
df.columns
# Out:
# Index(['Education', 'Marital_Status', 'Income', 'Kidhome', 'Teenhome',
#        'Recency', 'MntWines', 'MntFruits', 'MntMeatProducts',
#        'MntFishProducts', 'MntSweetProducts', 'MntGoldProds',
#        'NumDealsPurchases', 'NumWebPurchases', 'NumCatalogPurchases',
#        'NumStorePurchases', 'NumWebVisitsMonth', 'AcceptedCmp3',
#        'AcceptedCmp4', 'AcceptedCmp5', 'AcceptedCmp1', 'AcceptedCmp2',
#        'Complain', 'Z_CostContact', 'Z_Revenue', 'Response', 'Age',
#        'Total_Sped', 'Dt_Customer_year', 'Dt_Customer_Month'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

# create a figure with two subplots
fig, axs = plt.subplots(nrows=len(df.columns), ncols=2, figsize=(10, 5 * len(df.columns)))

# loop through each column and plot boxplot and histogram
for i, col in enumerate(df.columns):
    if df[col].dtype != 'object' and df[col].dtype != 'datetime64[ns]':
        # plot boxplot on first subplot
        axs[i, 0].boxplot(df[col])
        axs[i, 0].set_title(col)

        # plot histogram on second subplot
        axs[i, 1].hist(df[col], bins=10, alpha=0.5)
        axs[i, 1].set_title(col)

# set layout and show plot
plt.tight_layout()
plt.show()

# %% [markdown]
# # Encoading of String variables

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2109 entries, 0 to 2239
# Data columns (total 30 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Education            2109 non-null   object
#  1   Marital_Status       2109 non-null   object
#  2   Income               2109 non-null   float64
#  3   Kidhome              2109 non-null   int64
#  4   Teenhome             2109 non-null   int64
#  5   Recency              2109 non-null   int64
#  6   MntWines             2109 non-null   int64
#  7   MntFruits            2109 non-null   int64
#  8   MntMeatProducts      2109 non-null   int64
#  9   MntFishProducts      2109 non-null   int64
#  10  MntSweetProducts     2109 non-null   int64
#  11  MntGoldProds         2109 non-null   int64
#  12  NumDealsPurchases    2109 non-null   int64
#  13  NumWebPurchases      2109 non-null   int64
#  14  NumCatalogPurchases  2109 non-null   int64
# ...

# %% [markdown]
# We can see 2 variables (Education & Marital_Status) is of string data type.
#
# but we are not able to use string type variables in model building so we have to convert it in numeric type.
#
# for this we will use encoading of variables.

# %%
df.Education.value_counts()
# Out:
# Graduation         1057
# PhD                 456
# Master              353
# Undergraduation     243
# Name: Education, dtype: int64

# %% [markdown]
# Education Column is ordinal cetegorical column.
#
# We will replace string with numeric values by giving them weitage according to their ranks.
#
# For eg.:- '2nd Cycle' is higher then 'Basic', 'Graduation' is higher then '2n Cycle'.......

# %%
#Creating new column Using numpy's where function to replace string values with numeric values
df['Education_leb']=np.where(df['Education']== 'Undergraduation',0,
            np.where(df['Education']=='Graduation',1,
                        np.where(df['Education']=='Master',2,
                                 np.where(df['Education']=='PhD',3,df['Education']))))

# %%
# Checking that all the values replaced properly or not.
df[['Education','Education_leb']].sample(15)
# Out:
#             Education Education_leb
# 127            Master             2
# 2018       Graduation             1
# 681        Graduation             1
# 216   Undergraduation             0
# 1114              PhD             3
# 1471       Graduation             1
# 1136              PhD             3
# 23                PhD             3
# 1044       Graduation             1
# 2095              PhD             3
# 1169       Graduation             1
# 130        Graduation             1
# 672        Graduation             1
# 2076           Master             2
# 744        Graduation             1

# %%
# replacing orignal 'Education' with 'Education_leb' column.
df['Education']= df['Education_leb']

# %%
# droping 'Education_leb' column now from data.
df.drop('Education_leb',axis=1,inplace=True)

# %%
df.Marital_Status.value_counts()
# Out:
# Married      1366
# Unmarried     743
# Name: Marital_Status, dtype: int64

# %% [markdown]
# "Marital_Status" Column is nominal cetegorical column.
#
# We will create sepetrate columns for Both unique values with values 1 & 0, for True & False respectively.

# %%
df['Married']=np.where (df['Marital_Status']== 'Married', 1,
        np.where (df['Marital_Status']== 'Unmarried', 0, df['Marital_Status']))

# %%
df[['Marital_Status','Married']].sample(10).T
# Out:
#                    737      189      775      2121       96       1217  \
# Marital_Status  Married  Married  Married  Married  Unmarried  Married
# Married               1        1        1        1          0        1
#
#                    1678     1726     24         901
# Marital_Status  Married  Married  Married  Unmarried
# Married               1        1        1          0

# %%
df.drop(['Marital_Status'],axis=1,inplace=True)

# %%
df.head(5).T
# Out:
#                            0        1        2        3        4
# Education                  1        1        1        1        3
# Income               58138.0  46344.0  71613.0  26646.0  58293.0
# Kidhome                    0        1        0        1        1
# Teenhome                   0        1        0        0        0
# Recency                   58       38       26       26       94
# MntWines                 635       11      426       11      173
# MntFruits                 88        1       49        4       43
# MntMeatProducts          546        6      127       20      118
# MntFishProducts          172        2      111       10       46
# MntSweetProducts          88        1       21        3       27
# MntGoldProds              88        6       42        5       15
# NumDealsPurchases          3        2        1        2        5
# NumWebPurchases            8        1        8        2        5
# ...

# %%
df.shape
# Out:
# (2109, 30)

# %% [markdown]
# # Clustering

# %%
#standardization of data
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
data_std=scaler.fit_transform(df)

# %%
df_std=pd.DataFrame(data_std)
df_std
# Out:
#             0         1         2         3         4         5         6   \
# 0    -0.507254  0.361536 -0.845379 -0.945809  0.299967  1.033707  1.780650
# 1    -0.507254 -0.226129  1.006027  0.894331 -0.391621 -0.865937 -0.639258
# 2    -0.507254  1.032961 -0.845379 -0.945809 -0.806573  0.397448  0.695864
# 3    -0.507254 -1.207629  1.006027 -0.945809 -0.806573 -0.865937 -0.555813
# 4     1.586286  0.369259  1.006027 -0.945809  1.544824 -0.372760  0.528973
# ...        ...       ...       ...       ...       ...       ...       ...
# 2104 -0.507254  0.515254 -0.845379  0.894331 -0.114986  1.258986  0.528973
# 2105  1.586286  0.654322  2.857434  0.894331  0.230808  0.336562 -0.667073
# 2106 -0.507254  0.303886 -0.845379 -0.945809  1.441085  1.864802  0.668049
# 2107  0.539516  0.914969 -0.845379  0.894331 -1.429002  0.403537  0.167378
# 2108  1.586286  0.098995  1.006027  0.894331 -0.322462 -0.643703 -0.583628
#
# ...

# %% [markdown]
# # Hierarchical Clustering
# Linkages
#
# Types of Linkages:-
#
# 1) Single Leakage 2) Complete Linkage 3) Average Linkage 4)Ward Method

# %%
#Importing standard scaler library for transformation, & hierarchy from scipy for Hierarchical Clustering
import scipy.cluster.hierarchy as sch

# %% [markdown]
# # 1) Single Leakage:
# The distance between 2 clusters is defined as the shortest distance between points in the two clusters

# %%
plt.figure(figsize=(20,5))
plt.title("Companies customer data Dendogram")
dend = sch.dendrogram(sch.linkage(df_std, method='single'))
plt.xlabel('Customers')
plt.ylabel('Euclidean distances')
# Out:
# Text(0, 0.5, 'Euclidean distances')

# %% [markdown]
# # 2) Complete Linkage:
# The distance between 2 clusters is defined as the maximum distance between any 2 points in the clusters

# %%
plt.figure(figsize=(20,5))
plt.title("Crime Rate Dendograms")
dend = sch.dendrogram(sch.linkage(df_std, method='complete'))
plt.xlabel('Crime Rate')
plt.ylabel('Euclidean distances')
# Out:
# Text(0, 0.5, 'Euclidean distances')

# %% [markdown]
# # 3) Average Linkage:
# The distance between 2 clusters is defined as the average distance between every point of one cluster to every other point of the other cluster.

# %%
plt.figure(figsize=(20,5))
plt.title("Crime Rate Dendograms")
dend = sch.dendrogram(sch.linkage(df_std, method='average'))
plt.xlabel('Crime Rate')
plt.ylabel('Euclidean distances')
# Out:
# Text(0, 0.5, 'Euclidean distances')

# %% [markdown]
# # 4)Ward
# wardmethod is actually a method that tries to minimize the variance within each cluster.

# %%
plt.figure(figsize=(20,5))
plt.title("Crime Rate Dendograms")
dend = sch.dendrogram(sch.linkage(df_std, method='ward'))
plt.xlabel('Crime Rate')
plt.ylabel('Euclidean distances')
# Out:
# Text(0, 0.5, 'Euclidean distances')

# %% [markdown]
# # Observation:-
# With Single,complet & average Leakage clusters is not good structure vise, the dendograph is messy wecannot find optimumnumbers of cluster visually.
#
# With Ward clusters is well placed in shape of inverse tree.
#
# Effective numbers of cluster is 4, Beacause aswe go below 4 cluster the diffrence in Euclidean/Vertical distances is higher, but we will also use silhouette score method to find optimum numbers of cluster.

# %% [markdown]
# # Numbers Of Clusters
#
# Silhouette Score method.

# %%
from sklearn.metrics import silhouette_score
from sklearn.cluster import AgglomerativeClustering

# %%
for linkage in ['average','complete','single','ward']:
    for i in range(2, 21):
        hie_cluster1 = AgglomerativeClustering(n_clusters=i,linkage=linkage) # bydefault it takes linkage 'ward'
        hie_labels1 = hie_cluster1.fit_predict(data_std)
        silhouette_score1 = silhouette_score(data_std, hie_labels1)
        print(f"For n_clusters = {i}The {linkage} silhouette_score is :- {silhouette_score1}")
        print()
# Out:
# For n_clusters = 2The average silhouette_score is :- 0.4594889839518047
#
# For n_clusters = 3The average silhouette_score is :- 0.44021404369448086
#
# For n_clusters = 4The average silhouette_score is :- 0.4346209088927904
#
# For n_clusters = 5The average silhouette_score is :- 0.4000920728130551
#
# For n_clusters = 6The average silhouette_score is :- 0.397487363671693
#
# For n_clusters = 7The average silhouette_score is :- 0.31332374962251164
#
# For n_clusters = 8The average silhouette_score is :- 0.2975378535036056
#
# For n_clusters = 9The average silhouette_score is :- 0.292323783650869
#
# For n_clusters = 10The average silhouette_score is :- 0.29288032283050813
#
# For n_clusters = 11The average silhouette_score is :- 0.22764903811128478
#
# For n_clusters = 12The average silhouette_score is :- 0.20888293550722073
#
# For n_clusters = 13The average silhouette_score is :- 0.2076781786985696
#
# For n_clusters = 14The average silhouette_score is :- 0.19371111720811024
#
# ...

# %%
import matplotlib.pyplot as plt

silhouette_scores = {'average': [], 'complete': [], 'single': [], 'ward': []}

for linkage in ['average', 'complete', 'single', 'ward']:
    for i in range(2, 21):
        hie_cluster1 = AgglomerativeClustering(n_clusters=i, linkage=linkage)
        hie_labels1 = hie_cluster1.fit_predict(data_std)
        silhouette_score1 = silhouette_score(data_std, hie_labels1)
        silhouette_scores[linkage].append(silhouette_score1)

# Plotting the results
fig, ax = plt.subplots(2, 2, figsize=(10, 10))
axes = ax.flatten()

for i, linkage in enumerate(silhouette_scores.keys()):
    axes[i].plot(range(2, 21), silhouette_scores[linkage], marker='X')
    axes[i].set_title(linkage.capitalize() + " linkage")
    axes[i].set_xlabel("Number of clusters")
    axes[i].set_ylabel("Silhouette Score")

plt.tight_layout()
plt.show()

# %% [markdown]
# According to Average Linkage method silhoutte score is good till 6 number, between 6 and 7 number there is steep reduction in silhoutte score, we will create custering of 6 numbers.
#
# According to Complete Linkage method silhoutte score of number 2,3 is 0.44 and between 3 and 4 number score is directly droped to 0.25. and 3 number of cluster is very less.
#
# According to Single Linkage method silhoutte score is good till 5 number, between 5 and 6 number there is steep reduction in silhoutte score, we will create custering of 5 numbers.
#
#  And according to Ward linkage's silhoutte score is dropping after 2 numbers , and 2 number of cluster is very less.

# %% [markdown]
# # Creating Clusters with 6 Numbers Using Average Linkage

# %%
# Create Clusters
hc = AgglomerativeClustering(n_clusters=6, affinity = 'euclidean', linkage = 'average')

# %%
# save clusters for chart
_6_hc = hc.fit_predict(data_std)

# %%
df['Clusters']=_6_hc

# %%
# distribution of data in all clusters
df["Clusters"].value_counts().plot(kind='bar')
print(df["Clusters"].value_counts())
# Out:
# 0    2063
# 1      19
# 2      19
# 5       4
# 4       3
# 3       1
# Name: Clusters, dtype: int64

# %%
print(f'not good distribution as {(2063/2109)*100}% of data is lies in cluster 0')
# Out:
# not good distribution as 97.81887150308202% of data is lies in cluster 0

# %% [markdown]
# # Creating Clusters with 5 Numbers Using Single Linkage

# %%
# Create Clusters
hc = AgglomerativeClustering(n_clusters=5, affinity = 'euclidean', linkage = 'single')

# %%
# save clusters for chart
_5_hc = hc.fit_predict(data_std)
_5_hc
# Out:
# array([2, 2, 2, ..., 2, 2, 2], dtype=int64)

# %%
df.drop(['Clusters'],axis=1,inplace=True)

# %%
df['Clusters']=_5_hc

# %%
# distribution of data in all clusters
df["Clusters"].value_counts().plot(kind='bar')
print(df["Clusters"].value_counts())
# Out:
# 2    2063
# 0      22
# 1      19
# 4       4
# 3       1
# Name: Clusters, dtype: int64

# %%
print(f'not good distribution as {(2063/2116)*100}% of data is lies in cluster 0')
# Out:
# not good distribution as 97.49527410207939% of data is lies in cluster 0

# %% [markdown]
# # Creating Clusters with 3 Numbers using Complete Linkage

# %%
# Create Clusters
hc2 = AgglomerativeClustering(n_clusters=3, affinity = 'euclidean', linkage = 'complete')

# %%
# save clusters for chart
_3_hc = hc2.fit_predict(data_std)
_3_hc
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
df.drop(['Clusters'],axis=1,inplace=True)

# %%
df['Clusters']=_3_hc

# %%
# distribution of data in all clusters
df["Clusters"].value_counts().plot(kind='bar')
print(df["Clusters"].value_counts())
# Out:
# 0    2063
# 2      26
# 1      20
# Name: Clusters, dtype: int64

# %% [markdown]
# # Conclusion:-
# distribution of clustersis good.
#
# We ware geeting cluster number of 6,5 & 3 but distribution of data is not good.

# %% [markdown]
# # K_Means Clustering

# %%
from sklearn.cluster import KMeans
df_std.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2109 entries, 0 to 2108
# Data columns (total 30 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       2109 non-null   float64
#  1   1       2109 non-null   float64
#  2   2       2109 non-null   float64
#  3   3       2109 non-null   float64
#  4   4       2109 non-null   float64
#  5   5       2109 non-null   float64
#  6   6       2109 non-null   float64
#  7   7       2109 non-null   float64
#  8   8       2109 non-null   float64
#  9   9       2109 non-null   float64
#  10  10      2109 non-null   float64
#  11  11      2109 non-null   float64
#  12  12      2109 non-null   float64
#  13  13      2109 non-null   float64
#  14  14      2109 non-null   float64
#  15  15      2109 non-null   float64
#  16  16      2109 non-null   float64
#  17  17      2109 non-null   float64
#  18  18      2109 non-null   float64
#  19  19      2109 non-null   float64
# ...

# %%
wcss = []
for i in range(2, 11):
    kmeans = KMeans(n_clusters=i,random_state=0)
    kmeans.fit(df_std)
    wcss.append(kmeans.inertia_)

# %%
wcss
# Out:
# [46016.53539014516,
#  42218.04023279206,
#  39842.82833888897,
#  38354.68745756378,
#  36742.14327860559,
#  35428.983751658,
#  33468.123436509035,
#  32718.581252929704,
#  31712.456102228505]

# %%
wcss = []
for i in range(2, 11):
    kmeans = KMeans(n_clusters=i,random_state=0)
    kmeans.fit(df_std)
    wcss.append(kmeans.inertia_)

plt.figure(figsize=(10,6))    
plt.plot(range(2, 11), wcss,marker='X')
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.xticks(range(1, 11))
plt.ylabel('WCSS')
plt.show()

# %% [markdown]
# # Insight:-
# Form Elbow graph We can choose optimum numbers of clusters as 4 numbers of clusters.
#
# Lets check silhoutte score of diffrent number of clusters too.

# %%
for i in range(2, 11):
    KMean_cluster1 = KMeans(i, random_state=0)
    KMean_labels1 =  KMean_cluster1.fit_predict(data_std)
    silhouette_score1 = silhouette_score(data_std, KMean_labels1)
    print(f"For n_clusters = {i} silhouette_score is :- {silhouette_score1}")
    print()
# Out:
# For n_clusters = 2 silhouette_score is :- 0.2483140702224253
#
# For n_clusters = 3 silhouette_score is :- 0.16897649643781193
#
# For n_clusters = 4 silhouette_score is :- 0.16602054965993712
#
# For n_clusters = 5 silhouette_score is :- 0.08760572676511894
#
# For n_clusters = 6 silhouette_score is :- 0.09242339440817679
#
# For n_clusters = 7 silhouette_score is :- 0.09247498728035038
#
# For n_clusters = 8 silhouette_score is :- 0.09910271604575248
#
# For n_clusters = 9 silhouette_score is :- 0.09752395127728505
#
# For n_clusters = 10 silhouette_score is :- 0.09067618876129428

# %% [markdown]
# # Insight
# after 4 number of cluster with score 0.16 there is sudden drop in score for furter numbers.
#
# As we from Elbow graph and shiloutte score we are getting 4 number as optimum cluster numbers for KMeans clustring.

# %%
clusters_kmean_f = KMeans(4, random_state=0)
clusters_kmean_f.fit(data_std)
clusters_kmean_f.labels_
# Out:
# array([3, 1, 3, ..., 3, 3, 1])

# %%
df['Clusters']=clusters_kmean_f.labels_

# %%
# distribution of data in all clusters
df["Clusters"].value_counts().plot(kind='bar')
print(df["Clusters"].value_counts())
# Out:
# 1    993
# 2    542
# 3    433
# 0    141
# Name: Clusters, dtype: int64

# %%
print('% vise distribution of data :-\n')
    
print(f' {round((141/2109)*100,2)}% of data lies in Cluster 0')
print(f'{round((993/2109)*100,2)}% of data lies in Cluster 1')
print(f'{round((542/2109)*100,2)}%  of data lies in Cluster 2')
print(f'{round((433/2109)*100,2)}% of data lies in Cluster 3')
# Out:
# % vise distribution of data :-
#
#  6.69% of data lies in Cluster 0
# 47.08% of data lies in Cluster 1
# 25.7%  of data lies in Cluster 2
# 20.53% of data lies in Cluster 3

# %%
df.Clusters.describe()
# Out:
# count    2109.000000
# mean        1.600759
# std         0.885750
# min         0.000000
# 25%         1.000000
# 50%         1.000000
# 75%         2.000000
# max         3.000000
# Name: Clusters, dtype: float64

# %%
plt.hist(df.Clusters,bins=4)
# Out:
# (array([141., 993., 542., 433.]),
#  array([0.  , 0.75, 1.5 , 2.25, 3.  ]),
#  <BarContainer object of 4 artists>)

# %%
plt.boxplot(df.Clusters.value_counts())
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x28f99c859d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x28f99c85f70>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x28f99c85700>],
#  'medians': [<matplotlib.lines.Line2D at 0x28f99c95550>],
#  'fliers': [<matplotlib.lines.Line2D at 0x28f99c95820>],
#  'means': []}

# %% [markdown]
# # Insight
# From KMeans method we are getting best clustering. with good distribution of data.

# %% [markdown]
# # DBSCAN
# We are going to use the DBSCAN for algorithm for the purpose of clustering. It is an unsupervised machine learning algorithm. It is used for clusters of high density.

# %%
from sklearn.cluster import DBSCAN

# %%
for i in range(2, 11):
    dbscan = DBSCAN(eps=2, min_samples=25)
    dbscan_labels1 =  dbscan.fit_predict(data_std)
    silhouette_score1 = silhouette_score(data_std, dbscan_labels1)
    print(f"For n_clusters = {i} silhouette_score is :- {silhouette_score1}")
    print()
# Out:
# For n_clusters = 2 silhouette_score is :- -0.15389833532380415
#
# For n_clusters = 3 silhouette_score is :- -0.15389833532380415
#
# For n_clusters = 4 silhouette_score is :- -0.15389833532380415
#
# For n_clusters = 5 silhouette_score is :- -0.15389833532380415
#
# For n_clusters = 6 silhouette_score is :- -0.15389833532380415
#
# For n_clusters = 7 silhouette_score is :- -0.15389833532380415
#
# For n_clusters = 8 silhouette_score is :- -0.15389833532380415
#
# For n_clusters = 9 silhouette_score is :- -0.15389833532380415
#
# For n_clusters = 10 silhouette_score is :- -0.15389833532380415

# %%
dbscan = DBSCAN(eps=2, min_samples=25)
dbscan.fit(df_std)
# Out:
# DBSCAN(eps=2, min_samples=25)

# %%
#Noisy samples are given the label -1.
clusters=dbscan.labels_
clusters
# Out:
# array([-1, -1, -1, ..., -1, -1, -1], dtype=int64)

# %%
len(clusters[clusters==-1])
# Out:
# 1856

# %%
df['Clusters']=clusters

# %%
df.Clusters.value_counts()
# Out:
# -1    1856
#  0     188
#  2      40
#  1      25
# Name: Clusters, dtype: int64

# %% [markdown]
# # Data counts in each clusters.

# %%
bins=len(df.Clusters.value_counts())
plt.hist(df.Clusters,bins=bins,histtype='bar')
# Out:
# (array([1856.,  188.,   25.,   40.]),
#  array([-1.  , -0.25,  0.5 ,  1.25,  2.  ]),
#  <BarContainer object of 4 artists>)

# %% [markdown]
# Insight:-
# From DBscane after tuning hyper perameter by triel and error method we got 4 cluster.
#
# But the distribution of data in all cluster is not good

# %% [markdown]
# # Conclusion
# From Hierarchical Clustering:-
# We performed clustering with 6,5,3 number of cluster which are determind using shilhoutte score, but data is not uniformly distributed between clusters.
#
# From Kmeans Clustering:-
# We are getting 4 number as optimum number of clusters from Elbow graph and shiloutte score, and data is also uniformpy distributed among the clusters
#
# From DBScan Clustring:-
# From DBscane after tunning hyper perameter by triel and error method we got 4 cluster,But the distribution of data in all cluster is not good
#
#
# We will use Kmeans clustering with 4 number of clusters

# %%
import pickle
pickle_out= open('clusters_kmean_f.pkl','wb')
pickle.dump(clusters_kmean_f, pickle_out)
pickle_out.close()

# %%
df.columns
# Out:
# Index(['Education', 'Income', 'Kidhome', 'Teenhome', 'Recency', 'MntWines',
#        'MntFruits', 'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts',
#        'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases',
#        'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth',
#        'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5', 'AcceptedCmp1',
#        'AcceptedCmp2', 'Complain', 'Z_CostContact', 'Z_Revenue', 'Response',
#        'Age', 'Total_Sped', 'Dt_Customer_year', 'Dt_Customer_Month', 'Married',
#        'Clusters'],
#       dtype='object')

# %%
df.to_excel('fit.xlsx', index=False)

# %%
df.isna().sum()
# Out:
# Education              0
# Income                 0
# Kidhome                0
# Teenhome               0
# Recency                0
# MntWines               0
# MntFruits              0
# MntMeatProducts        0
# MntFishProducts        0
# MntSweetProducts       0
# MntGoldProds           0
# NumDealsPurchases      0
# NumWebPurchases        0
# NumCatalogPurchases    0
# NumStorePurchases      0
# NumWebVisitsMonth      0
# AcceptedCmp3           0
# AcceptedCmp4           0
# AcceptedCmp5           0
# AcceptedCmp1           0
# AcceptedCmp2           0
# Complain               0
# Z_CostContact          0
# Z_Revenue              0
# Response               0
# Age                    0
# Total_Sped             0
# Dt_Customer_year       0
# Dt_Customer_Month      0
# Married                0
# Clusters               0
# dtype: int64
